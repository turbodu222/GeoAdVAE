# %% [markdown]
# # Cross-Modal Alignment Training

# %% [markdown]
# ## Data Path Input

# %%
import os

# ========== Set Data Paths ==========
# Change this to your data directory
DATA_DIR = "{YOUR_DATA_PATH}"

os.environ['MORPHOLOGY_PATH'] = f"{DATA_DIR}/gw_dist.csv"
os.environ['GENE_EXPRESSION_PATH'] = f"{DATA_DIR}/gene_expression.csv"
os.environ['RNA_FAMILY_PATH'] = f"{DATA_DIR}/cluster_label_RNA.csv"
os.environ['MORPHO_CLUSTER_PATH'] = f"{DATA_DIR}/cluster_label_Morpho.csv"
os.environ['GEX_CLUSTER_PATH'] = f"{DATA_DIR}/cluster_label_GEX.csv"
os.environ['PRIOR_MATRIX_PATH'] = f"{DATA_DIR}/Corr_matrix.csv"

print("✓ Data paths configured")
# Out:
# ✓ Data paths configured

# %% [markdown]
# ## Running Model

# %%
from IPython.display import Image, display
import torch
import numpy as np
import random
import os

CONFIG = "{YOUR_MODEL_PATH}/{YOUR_MODEL_NAME}/configs/attempt_1.yaml"  # or your config path
OUTPUT = "{YOUR_OUTPUT_PATH}"


# !python {YOUR_MODEL_PATH}/{YOUR_MODEL_NAME}/train.py --config {CONFIG} --output_path {OUTPUT}

display(Image(filename=f'{OUTPUT}/outputs/attempt_1/images/_combined_final.png', width=700))

print("\n✓ Training completed!")
# Out:
# Loading cross-modal dataset...
# Loading morphology data...
# Loading gene expression data...
# Dataset size: 1000 samples
# Morphology dimensions: 1000
# Gene expression dimensions: 5
# Standardizing data...
# Loading RNA family labels...
# RNA family labels loaded: 5 unique types
# Loading morphology cluster labels...
# Morphology clusters: 3 unique clusters
# Morphology cluster range: 0-2
# Loading gene expression cluster labels...
# Gene expression clusters: 3 unique clusters
# GEX cluster range: 0-2
# Loading prior correlation matrix...
# Prior matrix shape: torch.Size([3, 3])
# Prior matrix range: 0.000000 to 1.000000
# Dataset initialization completed successfully!
#
# === Data Integrity Verification ===
# Sample count: 1000
# Morphology data shape: torch.Size([1000, 1000])
# Gene expression data shape: torch.Size([1000, 5])
# Morphology cluster labels shape: torch.Size([1000])
# GEX cluster labels shape: torch.Size([1000])
# RNA family labels shape: 1000
# ✓ All data components have consistent sizes
#
# === Sample Data Verification (First 5 samples) ===
# Sample 0: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 1: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 2: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 3: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 4: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Loss schedule configuration: {'kl_loss': 1, 'recon_loss': 1, 'gan_loss': 2, 'gw_loss': 3, 'prior_loss': 1}
# Training phase durations: {1: 100, 2: 200, 3: 200}
# Total training phases: 3
# Prior loss enabled with λ_p = 2
# Prior temperature = 0.1
# Prior matrix shape: torch.Size([3, 3])
# Prior loss will be activated in phase: 1
# Initializing GAN training debug system...
# Starting training with 1000 iterations
# Discriminator updates per iteration: 1
# Generator updates per iteration: 1
# Batch size: 16
#
# === Loss Schedule Configuration ===
# kl_loss     : starts from phase 1
# recon_loss  : starts from phase 1
# gan_loss    : starts from phase 2
# gw_loss     : starts from phase 3
# prior_loss  : starts from phase 1
#
# === Phase Duration Configuration ===
# Phase 1: iterations    0 -  100 (duration: 100)
# Phase 2: iterations  100 -  300 (duration: 200)
# Phase 3: iterations  300 -  500 (duration: 200)
# === Iteration 0/1000 - Phase 1 ===
# Active losses: ['kl_loss', 'recon_loss', 'prior_loss']
#
# === Cluster Label Verification at iteration 0 ===
# Batch sample 0 (global index 482): Morpho_cluster=1, GEX_cluster=1, RNA_family=SA
# Batch sample 1 (global index 466): Morpho_cluster=1, GEX_cluster=1, RNA_family=SA
# Batch sample 2 (global index 9): Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Prior loss debug - iteration 0:
#   Similarity range: -0.815 to 0.790
#   Target range: 0.000 to 1.000
#   Prior loss value: 0.000000
#   Warmup factor: 0.000
# ✓ VERIFIED: Discriminator weights unchanged during generator update
#
# === GAN Freeze Debug Verification at iteration 0 ===
# Testing discriminator training (generators should be frozen)...
# Checking requires_grad states during discriminator training:
#   Generator A frozen: True
#   Generator B frozen: True
#   Discriminator unfrozen: True
# ✓ VERIFIED: Generator A weights unchanged during discriminator training
# ✓ VERIFIED: Generator B weights unchanged during discriminator training
# ❌ ERROR: Discriminator weights did not change during training!
#
# Testing generator training (discriminator should be frozen)...
# Checking requires_grad states during generator training:
#   Generator A unfrozen: True
#   Generator B unfrozen: True
#   Discriminator frozen: True
# ✓ VERIFIED: Discriminator weights unchanged during generator training
# ❌ ERROR: Generator A weights did not change during training!
# ❌ ERROR: Generator B weights did not change during training!
# === GAN Freeze Debug Verification Complete ===
#
#
# === Loss Breakdown at Iter 0 Phase 1 ===
# Active losses in phase 1: ['kl_loss', 'recon_loss', 'prior_loss']
# Raw KL Loss: 4.433092
# Weighted KL: 0.443309 (weight: 0.1)
# Raw Recon: 3.436385
# Weighted Recon: 10.309156 (weight: 3)
# Raw Prior Loss: 0.000000
# Weighted Prior: 0.000000 (weight: 2)
# Total Loss: 10.752465
# ============================================================
#
# === Detailed Logging at iteration 25/1000 ===
# Training Phase: 1
# Active losses: ['kl_loss', 'recon_loss', 'prior_loss']
# Learning Rates - Generator: 0.001000, Discriminator: 0.001000
# Raw Losses:
#   kl_loss        : 4.358571 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 2.174022 (ACTIVE)
#   recon_loss_a   : 1.240417 (INACTIVE)
#   recon_loss_b   : 0.933605 (INACTIVE)
#   gan_loss       : 0.000000 (INACTIVE)
#   prior_loss     : 3.901216 (ACTIVE)
#   total_loss     : 14.760355 (INACTIVE)
# Weighted Losses:
#   kl_loss        : 0.435857 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 6.522067 (ACTIVE)
#   recon_loss_a   : 3.721252 (INACTIVE)
#   recon_loss_b   : 2.800814 (INACTIVE)
#   gan_loss       : 0.000000 (INACTIVE)
#   prior_loss     : 7.802432 (ACTIVE)
#   total_loss     : 14.760355 (INACTIVE)
# Latent Space Statistics:
#   Modality A - mean: -0.606, std: 2.769
#   Modality B - mean: -0.271, std: 1.179
#   Average cross-modal correlation: 0.947
#   Average cosine similarity: 0.929 ± 0.027
#   A→B evaluation: 1000 valid samples, 647 matches, accuracy: 0.6470
#   A→B evaluation: 1000 valid samples, 733 matches, accuracy: 0.7330
#   A→B evaluation: 1000 valid samples, 756 matches, accuracy: 0.7560
#   A→B evaluation: 1000 valid samples, 791 matches, accuracy: 0.7910
#   A→B evaluation: 1000 valid samples, 804 matches, accuracy: 0.8040
#   B→A evaluation: 1000 valid samples, 586 matches, accuracy: 0.5860
#   B→A evaluation: 1000 valid samples, 638 matches, accuracy: 0.6380
#   B→A evaluation: 1000 valid samples, 671 matches, accuracy: 0.6710
#   B→A evaluation: 1000 valid samples, 753 matches, accuracy: 0.7530
#   B→A evaluation: 1000 valid samples, 799 matches, accuracy: 0.7990
# Iteration: 24
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0050
# 5NN accuracy B→A: 0.0050
# 50NN accuracy A→B: 0.0460
# 50NN accuracy B→A: 0.0510
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.6470
# 3NN label accuracy A→B: 0.7330
# 5NN label accuracy A→B: 0.7560
# 10NN label accuracy A→B: 0.7910
# 20NN label accuracy A→B: 0.8040
# 1NN label accuracy B→A: 0.5860
# 3NN label accuracy B→A: 0.6380
# 5NN label accuracy B→A: 0.6710
# 10NN label accuracy B→A: 0.7530
# 20NN label accuracy B→A: 0.7990
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === Detailed Logging at iteration 50/1000 ===
# Training Phase: 1
# Active losses: ['kl_loss', 'recon_loss', 'prior_loss']
# Learning Rates - Generator: 0.001000, Discriminator: 0.001000
# Raw Losses:
#   kl_loss        : 8.915155 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 1.515987 (ACTIVE)
#   recon_loss_a   : 0.877733 (INACTIVE)
#   recon_loss_b   : 0.638253 (INACTIVE)
#   gan_loss       : 0.000000 (INACTIVE)
#   prior_loss     : 2.311256 (ACTIVE)
#   total_loss     : 10.061988 (INACTIVE)
# Weighted Losses:
#   kl_loss        : 0.891516 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 4.547960 (ACTIVE)
#   recon_loss_a   : 2.633200 (INACTIVE)
#   recon_loss_b   : 1.914760 (INACTIVE)
#   gan_loss       : 0.000000 (INACTIVE)
#   prior_loss     : 4.622512 (ACTIVE)
#   total_loss     : 10.061988 (INACTIVE)
# Latent Space Statistics:
#   Modality A - mean: -0.971, std: 3.201
#   Modality B - mean: -0.441, std: 1.273
#   Average cross-modal correlation: 0.939
#   Average cosine similarity: 0.925 ± 0.040
#   A→B evaluation: 1000 valid samples, 598 matches, accuracy: 0.5980
#   A→B evaluation: 1000 valid samples, 599 matches, accuracy: 0.5990
#   A→B evaluation: 1000 valid samples, 599 matches, accuracy: 0.5990
#   A→B evaluation: 1000 valid samples, 601 matches, accuracy: 0.6010
#   A→B evaluation: 1000 valid samples, 606 matches, accuracy: 0.6060
#   B→A evaluation: 1000 valid samples, 539 matches, accuracy: 0.5390
#   B→A evaluation: 1000 valid samples, 624 matches, accuracy: 0.6240
#   B→A evaluation: 1000 valid samples, 776 matches, accuracy: 0.7760
#   B→A evaluation: 1000 valid samples, 800 matches, accuracy: 0.8000
#   B→A evaluation: 1000 valid samples, 800 matches, accuracy: 0.8000
# Iteration: 49
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0060
# 5NN accuracy B→A: 0.0070
# 50NN accuracy A→B: 0.0490
# 50NN accuracy B→A: 0.0460
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.5980
# 3NN label accuracy A→B: 0.5990
# 5NN label accuracy A→B: 0.5990
# 10NN label accuracy A→B: 0.6010
# 20NN label accuracy A→B: 0.6060
# 1NN label accuracy B→A: 0.5390
# 3NN label accuracy B→A: 0.6240
# 5NN label accuracy B→A: 0.7760
# 10NN label accuracy B→A: 0.8000
# 20NN label accuracy B→A: 0.8000
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === GAN Freeze Debug Verification at iteration 50 ===
# Testing discriminator training (generators should be frozen)...
# Checking requires_grad states during discriminator training:
#   Generator A frozen: True
#   Generator B frozen: True
#   Discriminator unfrozen: True
# ✓ VERIFIED: Generator A weights unchanged during discriminator training
# ✓ VERIFIED: Generator B weights unchanged during discriminator training
# ❌ ERROR: Discriminator weights did not change during training!
#
# Testing generator training (discriminator should be frozen)...
# Checking requires_grad states during generator training:
#   Generator A unfrozen: True
#   Generator B unfrozen: True
#   Discriminator frozen: True
# ✓ VERIFIED: Discriminator weights unchanged during generator training
# ❌ ERROR: Generator A weights did not change during training!
# ❌ ERROR: Generator B weights did not change during training!
# === GAN Freeze Debug Verification Complete ===
#
#
# === Loss Breakdown at Iter 50 Phase 1 ===
# Active losses in phase 1: ['kl_loss', 'recon_loss', 'prior_loss']
# Raw KL Loss: 8.993511
# Weighted KL: 0.899351 (weight: 0.1)
# Raw Recon: 1.535774
# Weighted Recon: 4.607323 (weight: 3)
# Raw Prior Loss: 2.124297
# Weighted Prior: 4.248594 (weight: 2)
# Total Loss: 9.755268
# ============================================================
#
# === Detailed Logging at iteration 75/1000 ===
# Training Phase: 1
# Active losses: ['kl_loss', 'recon_loss', 'prior_loss']
# Learning Rates - Generator: 0.001000, Discriminator: 0.001000
# Raw Losses:
#   kl_loss        : 11.121094 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 1.151665 (ACTIVE)
#   recon_loss_a   : 0.695837 (INACTIVE)
#   recon_loss_b   : 0.455829 (INACTIVE)
#   gan_loss       : 0.000000 (INACTIVE)
#   prior_loss     : 1.119474 (ACTIVE)
#   total_loss     : 6.806053 (INACTIVE)
# Weighted Losses:
#   kl_loss        : 1.112109 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 3.454996 (ACTIVE)
#   recon_loss_a   : 2.087510 (INACTIVE)
#   recon_loss_b   : 1.367487 (INACTIVE)
#   gan_loss       : 0.000000 (INACTIVE)
#   prior_loss     : 2.238947 (ACTIVE)
#   total_loss     : 6.806053 (INACTIVE)
# Latent Space Statistics:
#   Modality A - mean: -1.376, std: 3.411
#   Modality B - mean: -0.479, std: 1.372
#   Average cross-modal correlation: 0.970
#   Average cosine similarity: 0.963 ± 0.016
#   A→B evaluation: 1000 valid samples, 614 matches, accuracy: 0.6140
#   A→B evaluation: 1000 valid samples, 620 matches, accuracy: 0.6200
#   A→B evaluation: 1000 valid samples, 623 matches, accuracy: 0.6230
#   A→B evaluation: 1000 valid samples, 626 matches, accuracy: 0.6260
#   A→B evaluation: 1000 valid samples, 643 matches, accuracy: 0.6430
#   B→A evaluation: 1000 valid samples, 489 matches, accuracy: 0.4890
#   B→A evaluation: 1000 valid samples, 758 matches, accuracy: 0.7580
#   B→A evaluation: 1000 valid samples, 777 matches, accuracy: 0.7770
#   B→A evaluation: 1000 valid samples, 800 matches, accuracy: 0.8000
#   B→A evaluation: 1000 valid samples, 800 matches, accuracy: 0.8000
# Iteration: 74
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0100
# 5NN accuracy B→A: 0.0060
# 50NN accuracy A→B: 0.0410
# 50NN accuracy B→A: 0.0480
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.6140
# 3NN label accuracy A→B: 0.6200
# 5NN label accuracy A→B: 0.6230
# 10NN label accuracy A→B: 0.6260
# 20NN label accuracy A→B: 0.6430
# 1NN label accuracy B→A: 0.4890
# 3NN label accuracy B→A: 0.7580
# 5NN label accuracy B→A: 0.7770
# 10NN label accuracy B→A: 0.8000
# 20NN label accuracy B→A: 0.8000
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === Detailed Logging at iteration 100/1000 ===
# Training Phase: 1
# Active losses: ['kl_loss', 'recon_loss', 'prior_loss']
# Learning Rates - Generator: 0.001000, Discriminator: 0.001000
# Raw Losses:
#   kl_loss        : 8.555346 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 0.872187 (ACTIVE)
#   recon_loss_a   : 0.540571 (INACTIVE)
#   recon_loss_b   : 0.331616 (INACTIVE)
#   gan_loss       : 0.000000 (INACTIVE)
#   prior_loss     : 0.937625 (ACTIVE)
#   total_loss     : 5.347348 (INACTIVE)
# Weighted Losses:
#   kl_loss        : 0.855535 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 2.616562 (ACTIVE)
#   recon_loss_a   : 1.621714 (INACTIVE)
#   recon_loss_b   : 0.994848 (INACTIVE)
#   gan_loss       : 0.000000 (INACTIVE)
#   prior_loss     : 1.875251 (ACTIVE)
#   total_loss     : 5.347348 (INACTIVE)
# Latent Space Statistics:
#   Modality A - mean: -0.938, std: 3.444
#   Modality B - mean: -0.517, std: 1.423
#   Average cross-modal correlation: 0.976
#   Average cosine similarity: 0.968 ± 0.016
#   A→B evaluation: 1000 valid samples, 626 matches, accuracy: 0.6260
#   A→B evaluation: 1000 valid samples, 630 matches, accuracy: 0.6300
#   A→B evaluation: 1000 valid samples, 633 matches, accuracy: 0.6330
#   A→B evaluation: 1000 valid samples, 640 matches, accuracy: 0.6400
#   A→B evaluation: 1000 valid samples, 686 matches, accuracy: 0.6860
#   B→A evaluation: 1000 valid samples, 656 matches, accuracy: 0.6560
#   B→A evaluation: 1000 valid samples, 798 matches, accuracy: 0.7980
#   B→A evaluation: 1000 valid samples, 799 matches, accuracy: 0.7990
#   B→A evaluation: 1000 valid samples, 800 matches, accuracy: 0.8000
#   B→A evaluation: 1000 valid samples, 800 matches, accuracy: 0.8000
# Iteration: 99
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0030
# 5NN accuracy B→A: 0.0060
# 50NN accuracy A→B: 0.0490
# 50NN accuracy B→A: 0.0440
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.6260
# 3NN label accuracy A→B: 0.6300
# 5NN label accuracy A→B: 0.6330
# 10NN label accuracy A→B: 0.6400
# 20NN label accuracy A→B: 0.6860
# 1NN label accuracy B→A: 0.6560
# 3NN label accuracy B→A: 0.7980
# 5NN label accuracy B→A: 0.7990
# 10NN label accuracy B→A: 0.8000
# 20NN label accuracy B→A: 0.8000
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === Saving checkpoint and plots at iteration 100 ===
# Loading cross-modal dataset...
# Loading morphology data...
# Loading gene expression data...
# Dataset size: 1000 samples
# Morphology dimensions: 1000
# Gene expression dimensions: 5
# Standardizing data...
# Loading RNA family labels...
# RNA family labels loaded: 5 unique types
# Loading morphology cluster labels...
# Morphology clusters: 3 unique clusters
# Morphology cluster range: 0-2
# Loading gene expression cluster labels...
# Gene expression clusters: 3 unique clusters
# GEX cluster range: 0-2
# Loading prior correlation matrix...
# Prior matrix shape: torch.Size([3, 3])
# Prior matrix range: 0.000000 to 1.000000
# Dataset initialization completed successfully!
#
# === Data Integrity Verification ===
# Sample count: 1000
# Morphology data shape: torch.Size([1000, 1000])
# Gene expression data shape: torch.Size([1000, 5])
# Morphology cluster labels shape: torch.Size([1000])
# GEX cluster labels shape: torch.Size([1000])
# RNA family labels shape: 1000
# ✓ All data components have consistent sizes
#
# === Sample Data Verification (First 5 samples) ===
# Sample 0: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 1: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 2: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 3: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 4: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Detected 1000 morphology samples and 1000 gene expression samples
# Using 1000 samples for PCA visualization
# Applied PCA - explained variance: [0.5419604  0.33416522]
# Found 5 unique labels: ['BI' 'PA' 'PB' 'SA' 'SB']
# Applied specific colors for known cell types:
# Checkpoint and plots saved successfully!
#
# ================================================================================
# PHASE TRANSITION at iteration 100
# From Phase 1 → Phase 2
# ================================================================================
# Active losses in Phase 2: ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# Newly activated losses: ['gan_loss']
# Phase 2 will last until iteration 300
# ================================================================================
#
# === Iteration 100/1000 - Phase 2 ===
# Active losses: ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# ✓ VERIFIED: Generator A weights unchanged during discriminator update
# ✓ VERIFIED: Generator B weights unchanged during discriminator update
# Prior loss debug - iteration 100:
#   Similarity range: -0.296 to 0.996
#   Target range: 0.000 to 1.000
#   Prior loss value: 0.956476
#   Warmup factor: 1.000
# ✓ VERIFIED: Discriminator weights unchanged during generator update
#
# === GAN Freeze Debug Verification at iteration 100 ===
# Testing discriminator training (generators should be frozen)...
# Checking requires_grad states during discriminator training:
#   Generator A frozen: True
#   Generator B frozen: True
#   Discriminator unfrozen: True
# ✓ VERIFIED: Generator A weights unchanged during discriminator training
# ✓ VERIFIED: Generator B weights unchanged during discriminator training
# ❌ ERROR: Discriminator weights did not change during training!
#
# Testing generator training (discriminator should be frozen)...
# Checking requires_grad states during generator training:
#   Generator A unfrozen: True
#   Generator B unfrozen: True
#   Discriminator frozen: True
# ✓ VERIFIED: Discriminator weights unchanged during generator training
# ❌ ERROR: Generator A weights did not change during training!
# ❌ ERROR: Generator B weights did not change during training!
# === GAN Freeze Debug Verification Complete ===
#
#
# === Loss Breakdown at Iter 100 Phase 2 ===
# Active losses in phase 2: ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# Raw KL Loss: 9.107218
# Weighted KL: 0.910722 (weight: 0.1)
# Raw Recon: 0.909157
# Weighted Recon: 2.727472 (weight: 3)
# Raw GAN Loss: 0.320226
# Weighted GAN: 6.404530 (weight: 20)
# Raw Prior Loss: 0.956476
# Weighted Prior: 1.912952 (weight: 2)
# Total Loss: 11.955675
# ============================================================
#
# === Detailed Logging at iteration 125/1000 ===
# Training Phase: 2
# Active losses: ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# Learning Rates - Generator: 0.001000, Discriminator: 0.001000
# Raw Losses:
#   kl_loss        : 9.787468 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 0.918030 (ACTIVE)
#   recon_loss_a   : 0.588172 (INACTIVE)
#   recon_loss_b   : 0.329857 (INACTIVE)
#   gan_loss       : 0.395270 (ACTIVE)
#   prior_loss     : 1.058268 (ACTIVE)
#   total_loss     : 13.754782 (INACTIVE)
# Weighted Losses:
#   kl_loss        : 0.978747 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 2.754089 (ACTIVE)
#   recon_loss_a   : 1.764517 (INACTIVE)
#   recon_loss_b   : 0.989572 (INACTIVE)
#   gan_loss       : 7.905409 (ACTIVE)
#   prior_loss     : 2.116536 (ACTIVE)
#   total_loss     : 13.754782 (INACTIVE)
# Latent Space Statistics:
#   Modality A - mean: -1.363, std: 2.965
#   Modality B - mean: -0.582, std: 1.457
#   Average cross-modal correlation: 0.992
#   Average cosine similarity: 0.986 ± 0.010
#   A→B evaluation: 1000 valid samples, 662 matches, accuracy: 0.6620
#   A→B evaluation: 1000 valid samples, 690 matches, accuracy: 0.6900
#   A→B evaluation: 1000 valid samples, 715 matches, accuracy: 0.7150
#   A→B evaluation: 1000 valid samples, 779 matches, accuracy: 0.7790
#   A→B evaluation: 1000 valid samples, 856 matches, accuracy: 0.8560
#   B→A evaluation: 1000 valid samples, 757 matches, accuracy: 0.7570
#   B→A evaluation: 1000 valid samples, 797 matches, accuracy: 0.7970
#   B→A evaluation: 1000 valid samples, 799 matches, accuracy: 0.7990
#   B→A evaluation: 1000 valid samples, 800 matches, accuracy: 0.8000
#   B→A evaluation: 1000 valid samples, 800 matches, accuracy: 0.8000
# Iteration: 124
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0110
# 5NN accuracy B→A: 0.0040
# 50NN accuracy A→B: 0.0600
# 50NN accuracy B→A: 0.0570
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.6620
# 3NN label accuracy A→B: 0.6900
# 5NN label accuracy A→B: 0.7150
# 10NN label accuracy A→B: 0.7790
# 20NN label accuracy A→B: 0.8560
# 1NN label accuracy B→A: 0.7570
# 3NN label accuracy B→A: 0.7970
# 5NN label accuracy B→A: 0.7990
# 10NN label accuracy B→A: 0.8000
# 20NN label accuracy B→A: 0.8000
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === Detailed Logging at iteration 150/1000 ===
# Training Phase: 2
# Active losses: ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# Learning Rates - Generator: 0.001000, Discriminator: 0.001000
# Raw Losses:
#   kl_loss        : 13.533298 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 0.870815 (ACTIVE)
#   recon_loss_a   : 0.538993 (INACTIVE)
#   recon_loss_b   : 0.331822 (INACTIVE)
#   gan_loss       : 0.475727 (ACTIVE)
#   prior_loss     : 0.992613 (ACTIVE)
#   total_loss     : 15.465533 (INACTIVE)
# Weighted Losses:
#   kl_loss        : 1.353330 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 2.612445 (ACTIVE)
#   recon_loss_a   : 1.616979 (INACTIVE)
#   recon_loss_b   : 0.995466 (INACTIVE)
#   gan_loss       : 9.514533 (ACTIVE)
#   prior_loss     : 1.985225 (ACTIVE)
#   total_loss     : 15.465533 (INACTIVE)
# Latent Space Statistics:
#   Modality A - mean: -0.971, std: 2.864
#   Modality B - mean: -0.564, std: 1.553
#   Average cross-modal correlation: 0.968
#   Average cosine similarity: 0.967 ± 0.018
#   A→B evaluation: 1000 valid samples, 659 matches, accuracy: 0.6590
#   A→B evaluation: 1000 valid samples, 724 matches, accuracy: 0.7240
#   A→B evaluation: 1000 valid samples, 743 matches, accuracy: 0.7430
#   A→B evaluation: 1000 valid samples, 797 matches, accuracy: 0.7970
#   A→B evaluation: 1000 valid samples, 865 matches, accuracy: 0.8650
#   B→A evaluation: 1000 valid samples, 521 matches, accuracy: 0.5210
#   B→A evaluation: 1000 valid samples, 553 matches, accuracy: 0.5530
#   B→A evaluation: 1000 valid samples, 569 matches, accuracy: 0.5690
#   B→A evaluation: 1000 valid samples, 643 matches, accuracy: 0.6430
#   B→A evaluation: 1000 valid samples, 719 matches, accuracy: 0.7190
# Iteration: 149
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0140
# 5NN accuracy B→A: 0.0070
# 50NN accuracy A→B: 0.0670
# 50NN accuracy B→A: 0.0670
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.6590
# 3NN label accuracy A→B: 0.7240
# 5NN label accuracy A→B: 0.7430
# 10NN label accuracy A→B: 0.7970
# 20NN label accuracy A→B: 0.8650
# 1NN label accuracy B→A: 0.5210
# 3NN label accuracy B→A: 0.5530
# 5NN label accuracy B→A: 0.5690
# 10NN label accuracy B→A: 0.6430
# 20NN label accuracy B→A: 0.7190
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === GAN Freeze Debug Verification at iteration 150 ===
# Testing discriminator training (generators should be frozen)...
# Checking requires_grad states during discriminator training:
#   Generator A frozen: True
#   Generator B frozen: True
#   Discriminator unfrozen: True
# ✓ VERIFIED: Generator A weights unchanged during discriminator training
# ✓ VERIFIED: Generator B weights unchanged during discriminator training
# ❌ ERROR: Discriminator weights did not change during training!
#
# Testing generator training (discriminator should be frozen)...
# Checking requires_grad states during generator training:
#   Generator A unfrozen: True
#   Generator B unfrozen: True
#   Discriminator frozen: True
# ✓ VERIFIED: Discriminator weights unchanged during generator training
# ❌ ERROR: Generator A weights did not change during training!
# ❌ ERROR: Generator B weights did not change during training!
# === GAN Freeze Debug Verification Complete ===
#
#
# === Loss Breakdown at Iter 150 Phase 2 ===
# Active losses in phase 2: ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# Raw KL Loss: 17.211121
# Weighted KL: 1.721112 (weight: 0.1)
# Raw Recon: 0.944422
# Weighted Recon: 2.833265 (weight: 3)
# Raw GAN Loss: 0.510314
# Weighted GAN: 10.206280 (weight: 20)
# Raw Prior Loss: 1.332368
# Weighted Prior: 2.664735 (weight: 2)
# Total Loss: 17.425392
# ============================================================
#
# === Detailed Logging at iteration 175/1000 ===
# Training Phase: 2
# Active losses: ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# Learning Rates - Generator: 0.001000, Discriminator: 0.001000
# Raw Losses:
#   kl_loss        : 10.599844 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 0.865171 (ACTIVE)
#   recon_loss_a   : 0.628208 (INACTIVE)
#   recon_loss_b   : 0.236963 (INACTIVE)
#   gan_loss       : 0.535820 (ACTIVE)
#   prior_loss     : 1.569564 (ACTIVE)
#   total_loss     : 17.511032 (INACTIVE)
# Weighted Losses:
#   kl_loss        : 1.059984 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 2.595514 (ACTIVE)
#   recon_loss_a   : 1.884625 (INACTIVE)
#   recon_loss_b   : 0.710889 (INACTIVE)
#   gan_loss       : 10.716404 (ACTIVE)
#   prior_loss     : 3.139129 (ACTIVE)
#   total_loss     : 17.511032 (INACTIVE)
# Latent Space Statistics:
#   Modality A - mean: -0.609, std: 2.230
#   Modality B - mean: -0.577, std: 1.637
#   Average cross-modal correlation: 0.939
#   Average cosine similarity: 0.933 ± 0.022
#   A→B evaluation: 1000 valid samples, 704 matches, accuracy: 0.7040
#   A→B evaluation: 1000 valid samples, 767 matches, accuracy: 0.7670
#   A→B evaluation: 1000 valid samples, 790 matches, accuracy: 0.7900
#   A→B evaluation: 1000 valid samples, 811 matches, accuracy: 0.8110
#   A→B evaluation: 1000 valid samples, 815 matches, accuracy: 0.8150
#   B→A evaluation: 1000 valid samples, 677 matches, accuracy: 0.6770
#   B→A evaluation: 1000 valid samples, 743 matches, accuracy: 0.7430
#   B→A evaluation: 1000 valid samples, 763 matches, accuracy: 0.7630
#   B→A evaluation: 1000 valid samples, 781 matches, accuracy: 0.7810
#   B→A evaluation: 1000 valid samples, 798 matches, accuracy: 0.7980
# Iteration: 174
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0110
# 5NN accuracy B→A: 0.0070
# 50NN accuracy A→B: 0.0610
# 50NN accuracy B→A: 0.0620
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.7040
# 3NN label accuracy A→B: 0.7670
# 5NN label accuracy A→B: 0.7900
# 10NN label accuracy A→B: 0.8110
# 20NN label accuracy A→B: 0.8150
# 1NN label accuracy B→A: 0.6770
# 3NN label accuracy B→A: 0.7430
# 5NN label accuracy B→A: 0.7630
# 10NN label accuracy B→A: 0.7810
# 20NN label accuracy B→A: 0.7980
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === Detailed Logging at iteration 200/1000 ===
# Training Phase: 2
# Active losses: ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# Learning Rates - Generator: 0.001000, Discriminator: 0.001000
# Raw Losses:
#   kl_loss        : 14.477672 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 0.940847 (ACTIVE)
#   recon_loss_a   : 0.678900 (INACTIVE)
#   recon_loss_b   : 0.261947 (INACTIVE)
#   gan_loss       : 0.596539 (ACTIVE)
#   prior_loss     : 0.433018 (ACTIVE)
#   total_loss     : 17.067129 (INACTIVE)
# Weighted Losses:
#   kl_loss        : 1.447767 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 2.822542 (ACTIVE)
#   recon_loss_a   : 2.036701 (INACTIVE)
#   recon_loss_b   : 0.785840 (INACTIVE)
#   gan_loss       : 11.930785 (ACTIVE)
#   prior_loss     : 0.866036 (ACTIVE)
#   total_loss     : 17.067129 (INACTIVE)
# Latent Space Statistics:
#   Modality A - mean: -0.301, std: 1.798
#   Modality B - mean: -0.598, std: 1.754
#   Average cross-modal correlation: 0.942
#   Average cosine similarity: 0.930 ± 0.028
#   A→B evaluation: 1000 valid samples, 807 matches, accuracy: 0.8070
#   A→B evaluation: 1000 valid samples, 823 matches, accuracy: 0.8230
#   A→B evaluation: 1000 valid samples, 839 matches, accuracy: 0.8390
#   A→B evaluation: 1000 valid samples, 864 matches, accuracy: 0.8640
#   A→B evaluation: 1000 valid samples, 882 matches, accuracy: 0.8820
#   B→A evaluation: 1000 valid samples, 668 matches, accuracy: 0.6680
#   B→A evaluation: 1000 valid samples, 715 matches, accuracy: 0.7150
#   B→A evaluation: 1000 valid samples, 746 matches, accuracy: 0.7460
#   B→A evaluation: 1000 valid samples, 771 matches, accuracy: 0.7710
#   B→A evaluation: 1000 valid samples, 791 matches, accuracy: 0.7910
# Iteration: 199
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0220
# 5NN accuracy B→A: 0.0150
# 50NN accuracy A→B: 0.1340
# 50NN accuracy B→A: 0.1180
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.8070
# 3NN label accuracy A→B: 0.8230
# 5NN label accuracy A→B: 0.8390
# 10NN label accuracy A→B: 0.8640
# 20NN label accuracy A→B: 0.8820
# 1NN label accuracy B→A: 0.6680
# 3NN label accuracy B→A: 0.7150
# 5NN label accuracy B→A: 0.7460
# 10NN label accuracy B→A: 0.7710
# 20NN label accuracy B→A: 0.7910
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === Saving checkpoint and plots at iteration 200 ===
# Loading cross-modal dataset...
# Loading morphology data...
# Loading gene expression data...
# Dataset size: 1000 samples
# Morphology dimensions: 1000
# Gene expression dimensions: 5
# Standardizing data...
# Loading RNA family labels...
# RNA family labels loaded: 5 unique types
# Loading morphology cluster labels...
# Morphology clusters: 3 unique clusters
# Morphology cluster range: 0-2
# Loading gene expression cluster labels...
# Gene expression clusters: 3 unique clusters
# GEX cluster range: 0-2
# Loading prior correlation matrix...
# Prior matrix shape: torch.Size([3, 3])
# Prior matrix range: 0.000000 to 1.000000
# Dataset initialization completed successfully!
#
# === Data Integrity Verification ===
# Sample count: 1000
# Morphology data shape: torch.Size([1000, 1000])
# Gene expression data shape: torch.Size([1000, 5])
# Morphology cluster labels shape: torch.Size([1000])
# GEX cluster labels shape: torch.Size([1000])
# RNA family labels shape: 1000
# ✓ All data components have consistent sizes
#
# === Sample Data Verification (First 5 samples) ===
# Sample 0: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 1: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 2: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 3: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 4: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Detected 1000 morphology samples and 1000 gene expression samples
# Using 1000 samples for PCA visualization
# Applied PCA - explained variance: [0.6368473  0.28198555]
# Found 5 unique labels: ['BI' 'PA' 'PB' 'SA' 'SB']
# Applied specific colors for known cell types:
# Checkpoint and plots saved successfully!
# === Iteration 200/1000 - Phase 2 ===
# Active losses: ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# ✓ VERIFIED: Generator A weights unchanged during discriminator update
# ✓ VERIFIED: Generator B weights unchanged during discriminator update
# Discriminator outputs - A: 0.458±0.122, B: 0.545±0.066
# Discriminator Analysis:
#   Output A (should be ~1): 0.472 ± 0.132
#   Output B (should be ~0): 0.540 ± 0.069
# Prior loss debug - iteration 200:
#   Similarity range: -0.357 to 0.983
#   Target range: 0.000 to 1.000
#   Prior loss value: 1.581907
#   Warmup factor: 1.000
# ✓ VERIFIED: Discriminator weights unchanged during generator update
#
# === GAN Freeze Debug Verification at iteration 200 ===
# Testing discriminator training (generators should be frozen)...
# Checking requires_grad states during discriminator training:
#   Generator A frozen: True
#   Generator B frozen: True
#   Discriminator unfrozen: True
# ✓ VERIFIED: Generator A weights unchanged during discriminator training
# ✓ VERIFIED: Generator B weights unchanged during discriminator training
# ❌ ERROR: Discriminator weights did not change during training!
#
# Testing generator training (discriminator should be frozen)...
# Checking requires_grad states during generator training:
#   Generator A unfrozen: True
#   Generator B unfrozen: True
#   Discriminator frozen: True
# ✓ VERIFIED: Discriminator weights unchanged during generator training
# ❌ ERROR: Generator A weights did not change during training!
# ❌ ERROR: Generator B weights did not change during training!
# === GAN Freeze Debug Verification Complete ===
#
#
# === Loss Breakdown at Iter 200 Phase 2 ===
# Active losses in phase 2: ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# Raw KL Loss: 7.361203
# Weighted KL: 0.736120 (weight: 0.1)
# Raw Recon: 0.809890
# Weighted Recon: 2.429670 (weight: 3)
# Raw GAN Loss: 0.399477
# Weighted GAN: 7.989545 (weight: 20)
# Raw Prior Loss: 1.581907
# Weighted Prior: 3.163815 (weight: 2)
# Total Loss: 14.319149
# ============================================================
#
# === Detailed Logging at iteration 225/1000 ===
# Training Phase: 2
# Active losses: ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# Learning Rates - Generator: 0.001000, Discriminator: 0.001000
# Raw Losses:
#   kl_loss        : 6.486925 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 0.690178 (ACTIVE)
#   recon_loss_a   : 0.464618 (INACTIVE)
#   recon_loss_b   : 0.225560 (INACTIVE)
#   gan_loss       : 0.323994 (ACTIVE)
#   prior_loss     : 0.698483 (ACTIVE)
#   total_loss     : 10.596078 (INACTIVE)
# Weighted Losses:
#   kl_loss        : 0.648692 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 2.070534 (ACTIVE)
#   recon_loss_a   : 1.393854 (INACTIVE)
#   recon_loss_b   : 0.676680 (INACTIVE)
#   gan_loss       : 6.479886 (ACTIVE)
#   prior_loss     : 1.396966 (ACTIVE)
#   total_loss     : 10.596078 (INACTIVE)
# Latent Space Statistics:
#   Modality A - mean: -0.462, std: 1.648
#   Modality B - mean: -0.667, std: 1.875
#   Average cross-modal correlation: 0.982
#   Average cosine similarity: 0.978 ± 0.009
#   A→B evaluation: 1000 valid samples, 921 matches, accuracy: 0.9210
#   A→B evaluation: 1000 valid samples, 941 matches, accuracy: 0.9410
#   A→B evaluation: 1000 valid samples, 949 matches, accuracy: 0.9490
#   A→B evaluation: 1000 valid samples, 964 matches, accuracy: 0.9640
#   A→B evaluation: 1000 valid samples, 980 matches, accuracy: 0.9800
#   B→A evaluation: 1000 valid samples, 815 matches, accuracy: 0.8150
#   B→A evaluation: 1000 valid samples, 848 matches, accuracy: 0.8480
#   B→A evaluation: 1000 valid samples, 856 matches, accuracy: 0.8560
#   B→A evaluation: 1000 valid samples, 873 matches, accuracy: 0.8730
#   B→A evaluation: 1000 valid samples, 891 matches, accuracy: 0.8910
# Iteration: 224
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0090
# 5NN accuracy B→A: 0.0150
# 50NN accuracy A→B: 0.1340
# 50NN accuracy B→A: 0.1490
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.9210
# 3NN label accuracy A→B: 0.9410
# 5NN label accuracy A→B: 0.9490
# 10NN label accuracy A→B: 0.9640
# 20NN label accuracy A→B: 0.9800
# 1NN label accuracy B→A: 0.8150
# 3NN label accuracy B→A: 0.8480
# 5NN label accuracy B→A: 0.8560
# 10NN label accuracy B→A: 0.8730
# 20NN label accuracy B→A: 0.8910
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === Detailed Logging at iteration 250/1000 ===
# Training Phase: 2
# Active losses: ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# Learning Rates - Generator: 0.001000, Discriminator: 0.001000
# Raw Losses:
#   kl_loss        : 8.066175 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 0.652111 (ACTIVE)
#   recon_loss_a   : 0.451095 (INACTIVE)
#   recon_loss_b   : 0.201015 (INACTIVE)
#   gan_loss       : 0.329878 (ACTIVE)
#   prior_loss     : 0.827168 (ACTIVE)
#   total_loss     : 11.014835 (INACTIVE)
# Weighted Losses:
#   kl_loss        : 0.806618 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 1.956332 (ACTIVE)
#   recon_loss_a   : 1.353286 (INACTIVE)
#   recon_loss_b   : 0.603046 (INACTIVE)
#   gan_loss       : 6.597551 (ACTIVE)
#   prior_loss     : 1.654335 (ACTIVE)
#   total_loss     : 11.014835 (INACTIVE)
# Latent Space Statistics:
#   Modality A - mean: -0.786, std: 2.094
#   Modality B - mean: -0.708, std: 1.864
#   Average cross-modal correlation: 0.980
#   Average cosine similarity: 0.980 ± 0.012
#   A→B evaluation: 1000 valid samples, 634 matches, accuracy: 0.6340
#   A→B evaluation: 1000 valid samples, 650 matches, accuracy: 0.6500
#   A→B evaluation: 1000 valid samples, 666 matches, accuracy: 0.6660
#   A→B evaluation: 1000 valid samples, 883 matches, accuracy: 0.8830
#   A→B evaluation: 1000 valid samples, 910 matches, accuracy: 0.9100
#   B→A evaluation: 1000 valid samples, 721 matches, accuracy: 0.7210
#   B→A evaluation: 1000 valid samples, 769 matches, accuracy: 0.7690
#   B→A evaluation: 1000 valid samples, 789 matches, accuracy: 0.7890
#   B→A evaluation: 1000 valid samples, 800 matches, accuracy: 0.8000
#   B→A evaluation: 1000 valid samples, 809 matches, accuracy: 0.8090
# Iteration: 249
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0070
# 5NN accuracy B→A: 0.0130
# 50NN accuracy A→B: 0.1300
# 50NN accuracy B→A: 0.1310
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.6340
# 3NN label accuracy A→B: 0.6500
# 5NN label accuracy A→B: 0.6660
# 10NN label accuracy A→B: 0.8830
# 20NN label accuracy A→B: 0.9100
# 1NN label accuracy B→A: 0.7210
# 3NN label accuracy B→A: 0.7690
# 5NN label accuracy B→A: 0.7890
# 10NN label accuracy B→A: 0.8000
# 20NN label accuracy B→A: 0.8090
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === GAN Freeze Debug Verification at iteration 250 ===
# Testing discriminator training (generators should be frozen)...
# Checking requires_grad states during discriminator training:
#   Generator A frozen: True
#   Generator B frozen: True
#   Discriminator unfrozen: True
# ✓ VERIFIED: Generator A weights unchanged during discriminator training
# ✓ VERIFIED: Generator B weights unchanged during discriminator training
# ❌ ERROR: Discriminator weights did not change during training!
#
# Testing generator training (discriminator should be frozen)...
# Checking requires_grad states during generator training:
#   Generator A unfrozen: True
#   Generator B unfrozen: True
#   Discriminator frozen: True
# ✓ VERIFIED: Discriminator weights unchanged during generator training
# ❌ ERROR: Generator A weights did not change during training!
# ❌ ERROR: Generator B weights did not change during training!
# === GAN Freeze Debug Verification Complete ===
#
#
# === Loss Breakdown at Iter 250 Phase 2 ===
# Active losses in phase 2: ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# Raw KL Loss: 7.863564
# Weighted KL: 0.786356 (weight: 0.1)
# Raw Recon: 0.689943
# Weighted Recon: 2.069829 (weight: 3)
# Raw GAN Loss: 0.344579
# Weighted GAN: 6.891575 (weight: 20)
# Raw Prior Loss: 0.705993
# Weighted Prior: 1.411986 (weight: 2)
# Total Loss: 11.159746
# ============================================================
#
# === Detailed Logging at iteration 275/1000 ===
# Training Phase: 2
# Active losses: ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# Learning Rates - Generator: 0.001000, Discriminator: 0.001000
# Raw Losses:
#   kl_loss        : 14.287846 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 0.825385 (ACTIVE)
#   recon_loss_a   : 0.599290 (INACTIVE)
#   recon_loss_b   : 0.226096 (INACTIVE)
#   gan_loss       : 0.471583 (ACTIVE)
#   prior_loss     : 0.442811 (ACTIVE)
#   total_loss     : 14.222223 (INACTIVE)
# Weighted Losses:
#   kl_loss        : 1.428785 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 2.476156 (ACTIVE)
#   recon_loss_a   : 1.797870 (INACTIVE)
#   recon_loss_b   : 0.678287 (INACTIVE)
#   gan_loss       : 9.431660 (ACTIVE)
#   prior_loss     : 0.885623 (ACTIVE)
#   total_loss     : 14.222223 (INACTIVE)
# Latent Space Statistics:
#   Modality A - mean: -0.781, std: 2.632
#   Modality B - mean: -0.793, std: 1.860
#   Average cross-modal correlation: 0.983
#   Average cosine similarity: 0.974 ± 0.010
#   A→B evaluation: 1000 valid samples, 833 matches, accuracy: 0.8330
#   A→B evaluation: 1000 valid samples, 857 matches, accuracy: 0.8570
#   A→B evaluation: 1000 valid samples, 864 matches, accuracy: 0.8640
#   A→B evaluation: 1000 valid samples, 880 matches, accuracy: 0.8800
#   A→B evaluation: 1000 valid samples, 888 matches, accuracy: 0.8880
#   B→A evaluation: 1000 valid samples, 747 matches, accuracy: 0.7470
#   B→A evaluation: 1000 valid samples, 767 matches, accuracy: 0.7670
#   B→A evaluation: 1000 valid samples, 781 matches, accuracy: 0.7810
#   B→A evaluation: 1000 valid samples, 792 matches, accuracy: 0.7920
#   B→A evaluation: 1000 valid samples, 800 matches, accuracy: 0.8000
# Iteration: 274
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0120
# 5NN accuracy B→A: 0.0110
# 50NN accuracy A→B: 0.1360
# 50NN accuracy B→A: 0.1310
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.8330
# 3NN label accuracy A→B: 0.8570
# 5NN label accuracy A→B: 0.8640
# 10NN label accuracy A→B: 0.8800
# 20NN label accuracy A→B: 0.8880
# 1NN label accuracy B→A: 0.7470
# 3NN label accuracy B→A: 0.7670
# 5NN label accuracy B→A: 0.7810
# 10NN label accuracy B→A: 0.7920
# 20NN label accuracy B→A: 0.8000
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === Detailed Logging at iteration 300/1000 ===
# Training Phase: 2
# Active losses: ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# Learning Rates - Generator: 0.001000, Discriminator: 0.001000
# Raw Losses:
#   kl_loss        : 7.877757 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 0.734984 (ACTIVE)
#   recon_loss_a   : 0.534727 (INACTIVE)
#   recon_loss_b   : 0.200257 (INACTIVE)
#   gan_loss       : 0.326462 (ACTIVE)
#   prior_loss     : 0.639602 (ACTIVE)
#   total_loss     : 10.801169 (INACTIVE)
# Weighted Losses:
#   kl_loss        : 0.787776 (ACTIVE)
#   gw_loss        : 0.000000 (INACTIVE)
#   recon_loss     : 2.204951 (ACTIVE)
#   recon_loss_a   : 1.604181 (INACTIVE)
#   recon_loss_b   : 0.600770 (INACTIVE)
#   gan_loss       : 6.529238 (ACTIVE)
#   prior_loss     : 1.279205 (ACTIVE)
#   total_loss     : 10.801169 (INACTIVE)
# Latent Space Statistics:
#   Modality A - mean: -0.472, std: 1.720
#   Modality B - mean: -0.772, std: 1.843
#   Average cross-modal correlation: 0.963
#   Average cosine similarity: 0.958 ± 0.013
#   A→B evaluation: 1000 valid samples, 844 matches, accuracy: 0.8440
#   A→B evaluation: 1000 valid samples, 869 matches, accuracy: 0.8690
#   A→B evaluation: 1000 valid samples, 883 matches, accuracy: 0.8830
#   A→B evaluation: 1000 valid samples, 918 matches, accuracy: 0.9180
#   A→B evaluation: 1000 valid samples, 944 matches, accuracy: 0.9440
#   B→A evaluation: 1000 valid samples, 679 matches, accuracy: 0.6790
#   B→A evaluation: 1000 valid samples, 690 matches, accuracy: 0.6900
#   B→A evaluation: 1000 valid samples, 707 matches, accuracy: 0.7070
#   B→A evaluation: 1000 valid samples, 729 matches, accuracy: 0.7290
#   B→A evaluation: 1000 valid samples, 807 matches, accuracy: 0.8070
# Iteration: 299
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0050
# 5NN accuracy B→A: 0.0200
# 50NN accuracy A→B: 0.0860
# 50NN accuracy B→A: 0.1150
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.8440
# 3NN label accuracy A→B: 0.8690
# 5NN label accuracy A→B: 0.8830
# 10NN label accuracy A→B: 0.9180
# 20NN label accuracy A→B: 0.9440
# 1NN label accuracy B→A: 0.6790
# 3NN label accuracy B→A: 0.6900
# 5NN label accuracy B→A: 0.7070
# 10NN label accuracy B→A: 0.7290
# 20NN label accuracy B→A: 0.8070
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === Saving checkpoint and plots at iteration 300 ===
# Loading cross-modal dataset...
# Loading morphology data...
# Loading gene expression data...
# Dataset size: 1000 samples
# Morphology dimensions: 1000
# Gene expression dimensions: 5
# Standardizing data...
# Loading RNA family labels...
# RNA family labels loaded: 5 unique types
# Loading morphology cluster labels...
# Morphology clusters: 3 unique clusters
# Morphology cluster range: 0-2
# Loading gene expression cluster labels...
# Gene expression clusters: 3 unique clusters
# GEX cluster range: 0-2
# Loading prior correlation matrix...
# Prior matrix shape: torch.Size([3, 3])
# Prior matrix range: 0.000000 to 1.000000
# Dataset initialization completed successfully!
#
# === Data Integrity Verification ===
# Sample count: 1000
# Morphology data shape: torch.Size([1000, 1000])
# Gene expression data shape: torch.Size([1000, 5])
# Morphology cluster labels shape: torch.Size([1000])
# GEX cluster labels shape: torch.Size([1000])
# RNA family labels shape: 1000
# ✓ All data components have consistent sizes
#
# === Sample Data Verification (First 5 samples) ===
# Sample 0: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 1: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 2: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 3: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 4: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Detected 1000 morphology samples and 1000 gene expression samples
# Using 1000 samples for PCA visualization
# Applied PCA - explained variance: [0.6593112  0.27915457]
# Found 5 unique labels: ['BI' 'PA' 'PB' 'SA' 'SB']
# Applied specific colors for known cell types:
# Checkpoint and plots saved successfully!
#
# ================================================================================
# PHASE TRANSITION at iteration 300
# From Phase 2 → Phase 3
# ================================================================================
# Active losses in Phase 3: ['kl_loss', 'recon_loss', 'gan_loss', 'gw_loss', 'prior_loss']
# Newly activated losses: ['gw_loss']
# Phase 3 will last until iteration 500
# ================================================================================
#
# === Iteration 300/1000 - Phase 3 ===
# Active losses: ['kl_loss', 'recon_loss', 'gan_loss', 'gw_loss', 'prior_loss']
# ✓ VERIFIED: Generator A weights unchanged during discriminator update
# ✓ VERIFIED: Generator B weights unchanged during discriminator update
# Prior loss debug - iteration 300:
#   Similarity range: -0.268 to 0.992
#   Target range: 0.000 to 1.000
#   Prior loss value: 0.696310
#   Warmup factor: 1.000
# ✓ VERIFIED: Discriminator weights unchanged during generator update
#
# === GAN Freeze Debug Verification at iteration 300 ===
# Testing discriminator training (generators should be frozen)...
# Checking requires_grad states during discriminator training:
#   Generator A frozen: True
#   Generator B frozen: True
#   Discriminator unfrozen: True
# ✓ VERIFIED: Generator A weights unchanged during discriminator training
# ✓ VERIFIED: Generator B weights unchanged during discriminator training
# ❌ ERROR: Discriminator weights did not change during training!
#
# Testing generator training (discriminator should be frozen)...
# Checking requires_grad states during generator training:
#   Generator A unfrozen: True
#   Generator B unfrozen: True
#   Discriminator frozen: True
# ✓ VERIFIED: Discriminator weights unchanged during generator training
# ❌ ERROR: Generator A weights did not change during training!
# ❌ ERROR: Generator B weights did not change during training!
# ...
#   A→B evaluation: 1000 valid samples, 943 matches, accuracy: 0.9430
#   A→B evaluation: 1000 valid samples, 959 matches, accuracy: 0.9590
#   A→B evaluation: 1000 valid samples, 962 matches, accuracy: 0.9620
#   A→B evaluation: 1000 valid samples, 971 matches, accuracy: 0.9710
#   A→B evaluation: 1000 valid samples, 973 matches, accuracy: 0.9730
#   B→A evaluation: 1000 valid samples, 960 matches, accuracy: 0.9600
#   B→A evaluation: 1000 valid samples, 991 matches, accuracy: 0.9910
#   B→A evaluation: 1000 valid samples, 996 matches, accuracy: 0.9960
#   B→A evaluation: 1000 valid samples, 996 matches, accuracy: 0.9960
#   B→A evaluation: 1000 valid samples, 998 matches, accuracy: 0.9980
# Iteration: 924
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0170
# 5NN accuracy B→A: 0.0230
# 50NN accuracy A→B: 0.1980
# 50NN accuracy B→A: 0.2510
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.9430
# 3NN label accuracy A→B: 0.9590
# 5NN label accuracy A→B: 0.9620
# 10NN label accuracy A→B: 0.9710
# 20NN label accuracy A→B: 0.9730
# 1NN label accuracy B→A: 0.9600
# 3NN label accuracy B→A: 0.9910
# 5NN label accuracy B→A: 0.9960
# 10NN label accuracy B→A: 0.9960
# 20NN label accuracy B→A: 0.9980
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === Detailed Logging at iteration 950/1000 ===
# Training Phase: 3
# Active losses: ['kl_loss', 'recon_loss', 'gan_loss', 'gw_loss', 'prior_loss']
# Learning Rates - Generator: 0.000250, Discriminator: 0.000250
# Raw Losses:
#   kl_loss        : 7.808777 (ACTIVE)
#   gw_loss        : 7.085131 (ACTIVE)
#   recon_loss     : 0.510589 (ACTIVE)
#   recon_loss_a   : 0.378877 (INACTIVE)
#   recon_loss_b   : 0.131712 (INACTIVE)
#   gan_loss       : 0.321813 (ACTIVE)
#   prior_loss     : 0.281484 (ACTIVE)
#   total_loss     : 10.020390 (INACTIVE)
# Weighted Losses:
#   kl_loss        : 0.780878 (ACTIVE)
#   gw_loss        : 0.708513 (ACTIVE)
#   recon_loss     : 1.531768 (ACTIVE)
#   recon_loss_a   : 1.136631 (INACTIVE)
#   recon_loss_b   : 0.395137 (INACTIVE)
#   gan_loss       : 6.436263 (ACTIVE)
#   prior_loss     : 0.562967 (ACTIVE)
#   total_loss     : 10.020390 (INACTIVE)
# Latent Space Statistics:
#   Modality A - mean: -0.762, std: 1.997
#   Modality B - mean: -0.694, std: 1.823
#   Average cross-modal correlation: 0.987
#   Average cosine similarity: 0.983 ± 0.009
#   A→B evaluation: 1000 valid samples, 948 matches, accuracy: 0.9480
#   A→B evaluation: 1000 valid samples, 962 matches, accuracy: 0.9620
#   A→B evaluation: 1000 valid samples, 966 matches, accuracy: 0.9660
#   A→B evaluation: 1000 valid samples, 974 matches, accuracy: 0.9740
#   A→B evaluation: 1000 valid samples, 979 matches, accuracy: 0.9790
#   B→A evaluation: 1000 valid samples, 946 matches, accuracy: 0.9460
#   B→A evaluation: 1000 valid samples, 996 matches, accuracy: 0.9960
#   B→A evaluation: 1000 valid samples, 997 matches, accuracy: 0.9970
#   B→A evaluation: 1000 valid samples, 999 matches, accuracy: 0.9990
#   B→A evaluation: 1000 valid samples, 999 matches, accuracy: 0.9990
# Iteration: 949
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0270
# 5NN accuracy B→A: 0.0260
# 50NN accuracy A→B: 0.2120
# 50NN accuracy B→A: 0.2340
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.9480
# 3NN label accuracy A→B: 0.9620
# 5NN label accuracy A→B: 0.9660
# 10NN label accuracy A→B: 0.9740
# 20NN label accuracy A→B: 0.9790
# 1NN label accuracy B→A: 0.9460
# 3NN label accuracy B→A: 0.9960
# 5NN label accuracy B→A: 0.9970
# 10NN label accuracy B→A: 0.9990
# 20NN label accuracy B→A: 0.9990
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === GAN Freeze Debug Verification at iteration 950 ===
# Testing discriminator training (generators should be frozen)...
# Checking requires_grad states during discriminator training:
#   Generator A frozen: True
#   Generator B frozen: True
#   Discriminator unfrozen: True
# ✓ VERIFIED: Generator A weights unchanged during discriminator training
# ✓ VERIFIED: Generator B weights unchanged during discriminator training
# ❌ ERROR: Discriminator weights did not change during training!
#
# Testing generator training (discriminator should be frozen)...
# Checking requires_grad states during generator training:
#   Generator A unfrozen: True
#   Generator B unfrozen: True
#   Discriminator frozen: True
# ✓ VERIFIED: Discriminator weights unchanged during generator training
# ❌ ERROR: Generator A weights did not change during training!
# ❌ ERROR: Generator B weights did not change during training!
# === GAN Freeze Debug Verification Complete ===
#
#
# === Loss Breakdown at Iter 950 Phase 3 ===
# Active losses in phase 3: ['kl_loss', 'recon_loss', 'gan_loss', 'gw_loss', 'prior_loss']
# Raw KL Loss: 8.222559
# Weighted KL: 0.822256 (weight: 0.1)
# Raw Recon: 0.453313
# Weighted Recon: 1.359940 (weight: 3)
# Raw GAN Loss: 0.321441
# Weighted GAN: 6.428827 (weight: 20)
# Raw GW Loss: 16.983374
# Weighted GW: 1.698337 (weight: 0.1)
# Raw Prior Loss: 0.250505
# Weighted Prior: 0.501010 (weight: 2)
# Total Loss: 10.810370
# ============================================================
#
# === Detailed Logging at iteration 975/1000 ===
# Training Phase: 3
# Active losses: ['kl_loss', 'recon_loss', 'gan_loss', 'gw_loss', 'prior_loss']
# Learning Rates - Generator: 0.000250, Discriminator: 0.000250
# Raw Losses:
#   kl_loss        : 8.591927 (ACTIVE)
#   gw_loss        : 1.039007 (ACTIVE)
#   recon_loss     : 0.554353 (ACTIVE)
#   recon_loss_a   : 0.397986 (INACTIVE)
#   recon_loss_b   : 0.156366 (INACTIVE)
#   gan_loss       : 0.312603 (ACTIVE)
#   prior_loss     : 0.222606 (ACTIVE)
#   total_loss     : 9.323433 (INACTIVE)
# Weighted Losses:
#   kl_loss        : 0.859193 (ACTIVE)
#   gw_loss        : 0.103901 (ACTIVE)
#   recon_loss     : 1.663058 (ACTIVE)
#   recon_loss_a   : 1.193959 (INACTIVE)
#   recon_loss_b   : 0.469099 (INACTIVE)
#   gan_loss       : 6.252068 (ACTIVE)
#   prior_loss     : 0.445213 (ACTIVE)
#   total_loss     : 9.323433 (INACTIVE)
# Latent Space Statistics:
#   Modality A - mean: -0.776, std: 1.985
#   Modality B - mean: -0.695, std: 1.827
#   Average cross-modal correlation: 0.988
#   Average cosine similarity: 0.985 ± 0.008
#   A→B evaluation: 1000 valid samples, 949 matches, accuracy: 0.9490
#   A→B evaluation: 1000 valid samples, 959 matches, accuracy: 0.9590
#   A→B evaluation: 1000 valid samples, 965 matches, accuracy: 0.9650
#   A→B evaluation: 1000 valid samples, 968 matches, accuracy: 0.9680
#   A→B evaluation: 1000 valid samples, 974 matches, accuracy: 0.9740
#   B→A evaluation: 1000 valid samples, 892 matches, accuracy: 0.8920
#   B→A evaluation: 1000 valid samples, 952 matches, accuracy: 0.9520
#   B→A evaluation: 1000 valid samples, 996 matches, accuracy: 0.9960
#   B→A evaluation: 1000 valid samples, 998 matches, accuracy: 0.9980
#   B→A evaluation: 1000 valid samples, 998 matches, accuracy: 0.9980
# Iteration: 974
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0130
# 5NN accuracy B→A: 0.0280
# 50NN accuracy A→B: 0.1930
# 50NN accuracy B→A: 0.2440
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.9490
# 3NN label accuracy A→B: 0.9590
# 5NN label accuracy A→B: 0.9650
# 10NN label accuracy A→B: 0.9680
# 20NN label accuracy A→B: 0.9740
# 1NN label accuracy B→A: 0.8920
# 3NN label accuracy B→A: 0.9520
# 5NN label accuracy B→A: 0.9960
# 10NN label accuracy B→A: 0.9980
# 20NN label accuracy B→A: 0.9980
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === Detailed Logging at iteration 1000/1000 ===
# Training Phase: 3
# Active losses: ['kl_loss', 'recon_loss', 'gan_loss', 'gw_loss', 'prior_loss']
# Learning Rates - Generator: 0.000250, Discriminator: 0.000250
# Raw Losses:
#   kl_loss        : 9.307976 (ACTIVE)
#   gw_loss        : 3.632931 (ACTIVE)
#   recon_loss     : 0.421719 (ACTIVE)
#   recon_loss_a   : 0.277137 (INACTIVE)
#   recon_loss_b   : 0.144582 (INACTIVE)
#   gan_loss       : 0.325053 (ACTIVE)
#   prior_loss     : 0.232757 (ACTIVE)
#   total_loss     : 9.525824 (INACTIVE)
# Weighted Losses:
#   kl_loss        : 0.930798 (ACTIVE)
#   gw_loss        : 0.363293 (ACTIVE)
#   recon_loss     : 1.265157 (ACTIVE)
#   recon_loss_a   : 0.831412 (INACTIVE)
#   recon_loss_b   : 0.433745 (INACTIVE)
#   gan_loss       : 6.501064 (ACTIVE)
#   prior_loss     : 0.465513 (ACTIVE)
#   total_loss     : 9.525824 (INACTIVE)
# Latent Space Statistics:
#   Modality A - mean: -0.760, std: 1.889
#   Modality B - mean: -0.689, std: 1.827
#   Average cross-modal correlation: 0.987
#   Average cosine similarity: 0.984 ± 0.008
#   A→B evaluation: 1000 valid samples, 951 matches, accuracy: 0.9510
#   A→B evaluation: 1000 valid samples, 959 matches, accuracy: 0.9590
#   A→B evaluation: 1000 valid samples, 961 matches, accuracy: 0.9610
#   A→B evaluation: 1000 valid samples, 963 matches, accuracy: 0.9630
#   A→B evaluation: 1000 valid samples, 970 matches, accuracy: 0.9700
#   B→A evaluation: 1000 valid samples, 937 matches, accuracy: 0.9370
#   B→A evaluation: 1000 valid samples, 987 matches, accuracy: 0.9870
#   B→A evaluation: 1000 valid samples, 995 matches, accuracy: 0.9950
#   B→A evaluation: 1000 valid samples, 995 matches, accuracy: 0.9950
#   B→A evaluation: 1000 valid samples, 996 matches, accuracy: 0.9960
# Iteration: 999
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0150
# 5NN accuracy B→A: 0.0290
# 50NN accuracy A→B: 0.1850
# 50NN accuracy B→A: 0.2320
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.9510
# 3NN label accuracy A→B: 0.9590
# 5NN label accuracy A→B: 0.9610
# 10NN label accuracy A→B: 0.9630
# 20NN label accuracy A→B: 0.9700
# 1NN label accuracy B→A: 0.9370
# 3NN label accuracy B→A: 0.9870
# 5NN label accuracy B→A: 0.9950
# 10NN label accuracy B→A: 0.9950
# 20NN label accuracy B→A: 0.9960
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
#
# === Saving checkpoint and plots at iteration 1000 ===
# Loading cross-modal dataset...
# Loading morphology data...
# Loading gene expression data...
# Dataset size: 1000 samples
# Morphology dimensions: 1000
# Gene expression dimensions: 5
# Standardizing data...
# Loading RNA family labels...
# RNA family labels loaded: 5 unique types
# Loading morphology cluster labels...
# Morphology clusters: 3 unique clusters
# Morphology cluster range: 0-2
# Loading gene expression cluster labels...
# Gene expression clusters: 3 unique clusters
# GEX cluster range: 0-2
# Loading prior correlation matrix...
# Prior matrix shape: torch.Size([3, 3])
# Prior matrix range: 0.000000 to 1.000000
# Dataset initialization completed successfully!
#
# === Data Integrity Verification ===
# Sample count: 1000
# Morphology data shape: torch.Size([1000, 1000])
# Gene expression data shape: torch.Size([1000, 5])
# Morphology cluster labels shape: torch.Size([1000])
# GEX cluster labels shape: torch.Size([1000])
# RNA family labels shape: 1000
# ✓ All data components have consistent sizes
#
# === Sample Data Verification (First 5 samples) ===
# Sample 0: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 1: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 2: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 3: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 4: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Detected 1000 morphology samples and 1000 gene expression samples
# Using 1000 samples for PCA visualization
# Applied PCA - explained variance: [0.6018277  0.31872094]
# Found 5 unique labels: ['BI' 'PA' 'PB' 'SA' 'SB']
# Applied specific colors for known cell types:
# Checkpoint and plots saved successfully!
#
# === Training Completed at iteration 1000 ===
# Generating final visualizations and saving loss curves...
#
# === Final Training Summary ===
# Phase 1 (duration 100): ['kl_loss', 'recon_loss', 'prior_loss']
# Phase 2 (duration 200): ['kl_loss', 'recon_loss', 'gan_loss', 'prior_loss']
# Phase 3 (duration 200): ['kl_loss', 'recon_loss', 'gan_loss', 'gw_loss', 'prior_loss']
# Loading cross-modal dataset...
# Loading morphology data...
# Loading gene expression data...
# Dataset size: 1000 samples
# Morphology dimensions: 1000
# Gene expression dimensions: 5
# Standardizing data...
# Loading RNA family labels...
# RNA family labels loaded: 5 unique types
# Loading morphology cluster labels...
# Morphology clusters: 3 unique clusters
# Morphology cluster range: 0-2
# Loading gene expression cluster labels...
# Gene expression clusters: 3 unique clusters
# GEX cluster range: 0-2
# Loading prior correlation matrix...
# Prior matrix shape: torch.Size([3, 3])
# Prior matrix range: 0.000000 to 1.000000
# Dataset initialization completed successfully!
#
# === Data Integrity Verification ===
# Sample count: 1000
# Morphology data shape: torch.Size([1000, 1000])
# Gene expression data shape: torch.Size([1000, 5])
# Morphology cluster labels shape: torch.Size([1000])
# GEX cluster labels shape: torch.Size([1000])
# RNA family labels shape: 1000
# ✓ All data components have consistent sizes
#
# === Sample Data Verification (First 5 samples) ===
# Sample 0: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 1: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 2: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 3: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Sample 4: Morpho_cluster=0, GEX_cluster=0, RNA_family=PA
# Detected 1000 morphology samples and 1000 gene expression samples
# Using 1000 samples for PCA visualization
# Applied PCA - explained variance: [0.6018275  0.31872076]
# Found 5 unique labels: ['BI' 'PA' 'PB' 'SA' 'SB']
# Applied specific colors for known cell types:
# Loss curves saved to: /home/users/turbodu/kzlinlab/projects/morpho_integration/out/turbo/writeup26/cm_VAE_v6_simu/outputs/attempt_1/training_loss_curves.png
# Log-scale loss curves saved to: /home/users/turbodu/kzlinlab/projects/morpho_integration/out/turbo/writeup26/cm_VAE_v6_simu/outputs/attempt_1/training_loss_curves_log.png
# Weighted loss curves saved to: /home/users/turbodu/kzlinlab/projects/morpho_integration/out/turbo/writeup26/cm_VAE_v6_simu/outputs/attempt_1/training_weighted_loss_curves.png
# Weighted log-scale loss curves saved to: /home/users/turbodu/kzlinlab/projects/morpho_integration/out/turbo/writeup26/cm_VAE_v6_simu/outputs/attempt_1/training_weighted_loss_curves_log.png
# Performing final evaluation...
#   A→B evaluation: 1000 valid samples, 951 matches, accuracy: 0.9510
#   A→B evaluation: 1000 valid samples, 959 matches, accuracy: 0.9590
#   A→B evaluation: 1000 valid samples, 961 matches, accuracy: 0.9610
#   A→B evaluation: 1000 valid samples, 963 matches, accuracy: 0.9630
#   A→B evaluation: 1000 valid samples, 970 matches, accuracy: 0.9700
#   B→A evaluation: 1000 valid samples, 937 matches, accuracy: 0.9370
#   B→A evaluation: 1000 valid samples, 987 matches, accuracy: 0.9870
#   B→A evaluation: 1000 valid samples, 995 matches, accuracy: 0.9950
#   B→A evaluation: 1000 valid samples, 995 matches, accuracy: 0.9950
#   B→A evaluation: 1000 valid samples, 996 matches, accuracy: 0.9960
# Iteration: final
# Low quality filtering: ENABLED (excluding 'low quality' from accuracy calculation)
# Total samples: 1000
# High quality samples: 1000
# Low quality samples: 0
#
# 5NN accuracy A→B: 0.0150
# 5NN accuracy B→A: 0.0290
# 50NN accuracy A→B: 0.1850
# 50NN accuracy B→A: 0.2320
# --- RNA Label Matching Accuracy (excluding 'low quality') ---
# 1NN label accuracy A→B: 0.9510
# 3NN label accuracy A→B: 0.9590
# 5NN label accuracy A→B: 0.9610
# 10NN label accuracy A→B: 0.9630
# 20NN label accuracy A→B: 0.9700
# 1NN label accuracy B→A: 0.9370
# 3NN label accuracy B→A: 0.9870
# 5NN label accuracy B→A: 0.9950
# 10NN label accuracy B→A: 0.9950
# 20NN label accuracy B→A: 0.9960
# Cell types evaluated: ['BI', 'PA', 'PB', 'SA', 'SB']
#
# Training completed successfully!
# All outputs saved to: /home/users/turbodu/kzlinlab/projects/morpho_integration/out/turbo/writeup26/cm_VAE_v6_simu/outputs/attempt_1
# Training finished successfully
# ✓ Training completed!
