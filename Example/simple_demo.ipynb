# %% [markdown]
# # Cross-Modal Alignment Training

# %% [markdown]
# ## Data Path Input

# %%
import os

# ========== Set Data Paths ==========
# Change this to your data directory
DATA_DIR = "{YOUR_DATA_PATH}"

os.environ['MORPHOLOGY_PATH'] = f"{DATA_DIR}/gw_dist.csv"
os.environ['GENE_EXPRESSION_PATH'] = f"{DATA_DIR}/gene_expression.csv"
os.environ['RNA_FAMILY_PATH'] = f"{DATA_DIR}/cluster_label.csv_RNA"
os.environ['MORPHO_CLUSTER_PATH'] = f"{DATA_DIR}/cluster_label.csv_Morpho"
os.environ['GEX_CLUSTER_PATH'] = f"{DATA_DIR}/cluster_label.csv_GEX"
os.environ['PRIOR_MATRIX_PATH'] = f"{DATA_DIR}/Corr_matrix.csv"

print("✓ Data paths configured")
# Out:
# ✓ Data paths configured

# %% [markdown]
# ## Running Model

# %%
from IPython.display import Image, display
import torch
import numpy as np
import random
import os

CONFIG = "{YOUR_MODEL_PATH}/{YOUR_MODEL_NAME}/configs/attempt_1.yaml"  # or your config path
OUTPUT = "{YOUR_OUTPUT_PATH}"


# !python {YOUR_MODEL_PATH}/{YOUR_MODEL_NAME}/train.py --config {CONFIG} --output_path {OUTPUT}

display(Image(filename=f'{OUTPUT}/outputs/attempt_1/images/_combined_final.png', width=700))

print("\n✓ Training completed!")
# Out:
# ✓ Random seed set to: 40
# Loading dataset...
# ✓ Dataset loaded
#
# Starting training...
#
# Training Progress: 100%|███████████████████████████████| 2000/2000 [02:13<00:00]
#
# Saving final results...
#
# Calculating final accuracy...
#
# ...
# FINAL RESULTS
# ...
#
# ✓ Cell Type Accuracy (k=1):
#   Morphology → Gene Expression: 1.0000
#   Gene Expression → Morphology: 1.0000
#   Average: 1.0000
#
# ✓ Integrated Plot:
#   Plot saved at: /home/users/turbodu/kzlinlab/projects/morpho_integration/out/turbo/writeup21/Output/outputs/attempt_1/images/_combined_final.png
#   Displaying plot...
#
# <IPython.core.display.Image object>
#
# ...
# Seed: 40
# Output directory: /home/users/turbodu/kzlinlab/projects/morpho_integration/out/turbo/writeup21/Output/outputs/attempt_1
# ...
# ✓ Training completed!
